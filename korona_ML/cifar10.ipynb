# %%
import tensorflow as tf
import os

from tensorflow.python.keras.datasets import cifar10
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from tensorflow.python.keras.utils import to_categorical
import numpy as np
np.random.seed(0)

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train.shape, X_test.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 19s 0us/step
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
plt.figure(figsize=(10,10))
for idx in range(25):
    plt.subplot(5, 5, idx+1)
    plt.imshow(X_train[idx+50], cmap='gray')
    plt.title('Class: {}'.format(y_train[idx+50]))
    
plt.tight_layout()

# %%
img_rows, img_cols= X_train.shape[1], X_train.shape[2]

num_channels = 3
X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, num_channels)
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, num_channels)

input_shape = (img_rows, img_cols, num_channels)

X_train.shape, X_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
if np.max(X_train) > 1: X_train = (X_train / 255)
if np.max(X_test) > 1: X_test = (X_test / 255)

# %%
if len(y_train.shape) == 2:
    y_train = y_train.reshape(-1)
    y_test = y_test.reshape(-1)
    
if len(y_train.shape) == 1:
    num_classes = len(set(y_train))
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

# %%
y_train.shape, y_test.shape, num_classes
# Out:
# ((50000, 10), (10000, 10), 10)

# %%
model = Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation = 'relu',
           input_shape=input_shape),
    Conv2D(filters=32, kernel_size=(3,3), activation = 'relu'),
    MaxPool2D(pool_size=(2,2)),
    Dropout(0.25),
    
    Conv2D(filters=64, kernel_size=(3,3), activation = 'relu'),
    Conv2D(filters=64, kernel_size=(3,3), activation = 'relu'),  
    MaxPool2D(pool_size=(2,2)),
    Dropout(0.25),
    
    
    Conv2D(filters=128, kernel_size=(3,3), activation = 'relu'),  
    MaxPool2D(pool_size=(2,2)),
    Dropout(0.25),
    
    Flatten(),
    
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

# %%
TPU_WORKER = 'grpc://' + os.environ['COLAB_TPU_ADDR']
tf.logging.set_verbosity(tf.logging.INFO)

# %%
tpu_model = tf.contrib.tpu.keras_to_tpu_model(
model,
strategy=tf.contrib.tpu.TPUDistributionStrategy(
tf.contrib.cluster_resolver.TPUClusterResolver(TPU_WORKER)))
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Querying Tensorflow master (grpc://10.125.45.130:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 7349910350435812357)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 15726328583887516838)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 1278687570581345639)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 16805568335437538122)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 4265724172050610681)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 5418290827632607896)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 13788386489912495930)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 710518201435854768)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 11141087677690173906)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 7248515561716462628)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 5791683954609744425)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}

# %%
tpu_model.fit(
    X_train, y_train,
    batch_size=128*8,
    epochs=20,
    validation_split=0.2
)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(128,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(128, 32, 32, 3), dtype=tf.float32, name='conv2d_15_input_10'), TensorSpec(shape=(128, 10), dtype=tf.float32, name='dense_7_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for conv2d_15_input
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7ff6bfeda6d8> []
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 3.74635648727417 secs
# INFO:tensorflow:Setting weights on TPU model.
# INFO:tensorflow:CPU -> TPU lr: 0.0010000000474974513 {0.001}
# INFO:tensorflow:CPU -> TPU beta_1: 0.8999999761581421 {0.9}
# INFO:tensorflow:CPU -> TPU beta_2: 0.9990000128746033 {0.999}
# INFO:tensorflow:CPU -> TPU decay: 0.0 {0.0}
# WARNING:tensorflow:Cannot update non-variable config: epsilon
# WARNING:tensorflow:Cannot update non-variable config: amsgrad
# 48128/50000 [===========================>..] - ETA: 0s - loss: 2.1007 - acc: 0.2015INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(106,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(106, 32, 32, 3), dtype=tf.float32, name='conv2d_15_input_10'), TensorSpec(shape=(106, 10), dtype=tf.float32, name='dense_7_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_15_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7ff6bfeda6d8> [<tf.Variable 'tpu_140697808411616/Adam/iterations:0' shape=() dtype=int64>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bf082908>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bf03dc50>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bf029518>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bf006a20>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6befd0e80>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bef1bf28>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bef3e7b8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6beecfa90>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bee165c0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bee3bf60>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bee037b8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bedcc160>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6becdca90>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bed032b0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bec71dd8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bec90cf8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bebdbba8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bebc87b8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6beb91400>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6beafc9e8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6beac7e48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bea90f28>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6bea357b8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be9a4ac8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be968668>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be8d6908>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be8fca58>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be867860>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be832400>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be79c668>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be7669e8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be788630>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be69aa90>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be6c1e80>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be62c9e8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be599550>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7ff6be561a90>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x ...
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 4.013965845108032 secs
# 49152/50000 [============================>.] - ETA: 0s - loss: 2.0975 - acc: 0.2028INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(128,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(128, 32, 32, 3), dtype=tf.float32, name='conv2d_15_input_10'), TensorSpec(shape=(128, 10), dtype=tf.float32, name='dense_7_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for conv2d_15_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7ff6bbe1e7b8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 2.9374239444732666 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(98,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(98, 32, 32, 3), dtype=tf.float32, name='conv2d_15_input_10'), TensorSpec(shape=(98, 10), dtype=tf.float32, name='dense_7_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_15_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7ff6bbe1e7b8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 1.8862054347991943 secs
# 50000/50000 [==============================] - 37s 734us/sample - loss: 2.0946 - acc: 0.2034 - val_loss: 2.3833 - val_acc: 0.1783
# Epoch 2/20
# 50000/50000 [==============================] - 7s 143us/sample - loss: 1.9179 - acc: 0.2843 - val_loss: 3.4322 - val_acc: 0.1256
# Epoch 3/20
# 50000/50000 [==============================] - 8s 151us/sample - loss: 1.9977 - acc: 0.2830 - val_loss: 2.7879 - val_acc: 0.1792
# Epoch 4/20
# 50000/50000 [==============================] - 8s 151us/sample - loss: 1.8320 - acc: 0.3313 - val_loss: 2.5546 - val_acc: 0.2090
# Epoch 5/20
# 50000/50000 [==============================] - 8s 151us/sample - loss: 1.7808 - acc: 0.3537 - val_loss: 2.3419 - val_acc: 0.2254
# Epoch 6/20
# 50000/50000 [==============================] - 8s 152us/sample - loss: 1.7190 - acc: 0.3737 - val_loss: 1.8116 - val_acc: 0.3524
# Epoch 7/20
# 50000/50000 [==============================] - 7s 148us/sample - loss: 1.5726 - acc: 0.4204 - val_loss: 2.0297 - val_acc: 0.2917
# Epoch 8/20
# 50000/50000 [==============================] - 8s 151us/sample - loss: 1.5488 - acc: 0.4346 - val_loss: 1.9733 - val_acc: 0.3132
# Epoch 9/20
# 50000/50000 [==============================] - 8s 151us/sample - loss: 1.5208 - acc: 0.4471 - val_loss: 2.1223 - val_acc: 0.2744
# Epoch 10/20
# 50000/50000 [==============================] - 7s 150us/sample - loss: 1.5150 - acc: 0.4487 - val_loss: 1.6601 - val_acc: 0.3752
# Epoch 11/20
# 50000/50000 [==============================] - 7s 145us/sample - loss: 1.4057 - acc: 0.4867 - val_loss: 1.4397 - val_acc: 0.4824
# Epoch 12/20
# 50000/50000 [==============================] - 7s 148us/sample - loss: 1.3203 - acc: 0.5235 - val_loss: 1.5725 - val_acc: 0.4244
# Epoch 13/20
# 50000/50000 [==============================] - 8s 154us/sample - loss: 1.3256 - acc: 0.5224 - val_loss: 3.8662 - val_acc: 0.1952
# Epoch 14/20
# 50000/50000 [==============================] - 8s 153us/sample - loss: 1.5928 - acc: 0.4414 - val_loss: 2.5477 - val_acc: 0.2897
# Epoch 15/20
# 50000/50000 [==============================] - 8s 154us/sample - loss: 1.5517 - acc: 0.4478 - val_loss: 1.8064 - val_acc: 0.4035
# Epoch 16/20
# 50000/50000 [==============================] - 7s 146us/sample - loss: 1.3645 - acc: 0.5154 - val_loss: 1.6865 - val_acc: 0.4351
# Epoch 17/20
# 50000/50000 [==============================] - 8s 151us/sample - loss: 1.3129 - acc: 0.5352 - val_loss: 1.7835 - val_acc: 0.4227
# Epoch 18/20
# 50000/50000 [==============================] - 8s 152us/sample - loss: 1.2943 - acc: 0.5448 - val_loss: 1.6093 - val_acc: 0.4795
# Epoch 19/20
# 50000/50000 [==============================] - 8s 155us/sample - loss: 1.2348 - acc: 0.5647 - val_loss: 1.4965 - val_acc: 0.4730
# Epoch 20/20
# 50000/50000 [==============================] - 8s 152us/sample - loss: 1.1869 - acc: 0.5797 - val_loss: 1.1997 - val_acc: 0.5756

# %%
tpu_model.evaluate(X_test, y_test)
# Out:
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(4, 32, 32, 3), dtype=tf.float32, name='conv2d_15_input_10'), TensorSpec(shape=(4, 10), dtype=tf.float32, name='dense_7_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_15_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7ff6bbe1e7b8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 1.8620426654815674 secs
#  9856/10000 [============================>.] - ETA: 0s - loss: 1.2684 - acc: 0.5570INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(2,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(2, 32, 32, 3), dtype=tf.float32, name='conv2d_15_input_10'), TensorSpec(shape=(2, 10), dtype=tf.float32, name='dense_7_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_15_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7ff6bbe1e7b8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 2.028193950653076 secs
# 10000/10000 [==============================] - 8s 832us/sample - loss: 1.2691 - acc: 0.5565
# [1.2691274869918823, 0.55649996]
